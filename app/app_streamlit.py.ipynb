# %%
import streamlit as st
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

# -----------------------------
# 1️⃣ Load the trained model
# -----------------------------
model = joblib.load('../models/rf_vol_model.joblib')

st.set_page_config(page_title="Crypto Volatility Predictor", layout="wide")
st.title("💹 Crypto Volatility Prediction App")

st.markdown("""
This app predicts the **next 7-day volatility** of a cryptocurrency  
based on recent technical indicators.
""")

# -----------------------------
# 2️⃣ Sidebar input section
# -----------------------------
st.sidebar.header("Input Feature Values")
st.sidebar.markdown("Enter the latest data values below:")

# User inputs
volatility_7d = st.sidebar.number_input("7-Day Volatility", min_value=0.0, max_value=1.0, value=0.3)
volatility_21d = st.sidebar.number_input("21-Day Volatility", min_value=0.0, max_value=1.0, value=0.25)
log_return = st.sidebar.number_input("Log Return", min_value=-0.2, max_value=0.2, value=0.01)
ma_7 = st.sidebar.number_input("7-Day Moving Average", min_value=0.0, value=40000.0)
ma_21 = st.sidebar.number_input("21-Day Moving Average", min_value=0.0, value=38000.0)
vol_ratio = st.sidebar.number_input("Volume Ratio", min_value=0.0, max_value=3.0, value=1.2)

# Combine inputs into a DataFrame
input_data = pd.DataFrame({
    'volatility_7d': [volatility_7d],
    'volatility_21d': [volatility_21d],
    'log_return': [log_return],
    'ma_7': [ma_7],
    'ma_21': [ma_21],
    'vol_ratio': [vol_ratio]
})

st.subheader("🔢 Input Summary")
st.write(input_data)

# -----------------------------
# 3️⃣ Make prediction
# -----------------------------
if st.button("Predict Volatility"):
    prediction = model.predict(input_data)[0]
    st.success(f"Predicted 7-Day Volatility: **{prediction:.4f}**")

    # Show interpretation
    if prediction < 0.2:
        st.info("Market seems **Stable / Low Volatility** 🟢")
    elif prediction < 0.5:
        st.warning("Market showing **Moderate Volatility** 🟠")
    else:
        st.error("Market is **Highly Volatile** 🔴")

    # -----------------------------
    # 4️⃣ Show small visualization
    # -----------------------------
    st.subheader("📈 Prediction Visualization")
    fig, ax = plt.subplots(figsize=(6,4))
    bars = ax.bar(["Predicted Volatility"], [prediction], color=['skyblue'])
    ax.set_ylim(0, 1)
    plt.ylabel("Volatility Level")
    plt.title("Predicted 7-Day Volatility")
    st.pyplot(fig)

else:
    st.info("Click **Predict Volatility** after entering values.")

# -----------------------------
# 5️⃣ Footer
# -----------------------------
st.markdown("---")
st.caption("Built by Shwet Anand |  Data Analyst Project | © 2025")
# Out:
# 2025-11-03 13:44:53.114 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:53.116 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.588
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\shwet\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-03 13:44:54.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.590 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.592 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.597 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.601 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.604 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.606 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.608 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.609 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.612 Session state does not function when running a script without `streamlit run`
# 2025-11-03 13:44:54.613 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.615 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.616 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.618 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.619 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.620 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.622 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.624 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.625 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.630 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.631 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.634 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.635 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.641 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.644 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.646 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.647 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.649 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.656 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.666 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.698 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.703 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.704 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.709 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.712 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-03 13:44:54.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
